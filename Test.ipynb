# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("WHO COVID-19 global table data July 8th 2021 at 7.05.52 PM.csv",sep=',')

# %%
df
# Out:
#                          Name       WHO Region  Cases - cumulative total  \
# 0                      Global              NaN                 184820132
# 1    United States of America         Americas                  33429396
# 2                       India  South-East Asia                  30709557
# 3                      Brazil         Americas                  18855015
# 4          Russian Federation           Europe                   5707452
# ..                        ...              ...                       ...
# 233              Saint Helena           Africa                         0
# 234                   Tokelau  Western Pacific                         0
# 235                     Tonga  Western Pacific                         0
# 236              Turkmenistan           Europe                         0
# 237                    Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 100000 population  \
# ...

# %%
new_mbusa=df.loc[(df['WHO Region']=='Americas')]
new_mbusa
# Out:
#                                    Name WHO Region  Cases - cumulative total  \
# 1              United States of America   Americas                  33429396
# 3                                Brazil   Americas                  18855015
# 8                             Argentina   Americas                   4574340
# 9                              Colombia   Americas                   4402582
# 15                               Mexico   Americas                   2549862
# 19                                 Peru   Americas                   2069051
# 22                                Chile   Americas                   1576336
# 24                               Canada   Americas                   1418080
# 46                              Ecuador   Americas                    465029
# 48     Bolivia (Plurinational State of)   Americas                    448213
# 49                             Paraguay   Americas                    431367
# ...

# %%
new_mbusa.head()
# Out:
#                         Name WHO Region  Cases - cumulative total  \
# 1   United States of America   Americas                  33429396
# 3                     Brazil   Americas                  18855015
# 8                  Argentina   Americas                   4574340
# 9                   Colombia   Americas                   4402582
# 15                    Mexico   Americas                   2549862
#
#     Cases - cumulative total per 100000 population  \
# 1                                         10099.43
# 3                                          8870.47
# 8                                         10121.17
# 9                                          8652.38
# 15                                         1977.67
#
#     Cases - newly reported in last 7 days  \
# 1                                   96394
# 3                                  341710
# 8                                  126639
# 9                                  189508
# ...

# %%
new_mbusa.tail()
# Out:
#                             Name WHO Region  Cases - cumulative total  \
# 213  Falkland Islands (Malvinas)   Americas                        60
# 216    Saint Pierre and Miquelon   Americas                        26
# 217                   Montserrat   Americas                        20
# 218               Sint Eustatius   Americas                        20
# 220                         Saba   Americas                         7
#
#      Cases - cumulative total per 100000 population  \
# 213                                         1722.65
# 216                                          448.66
# 217                                          400.08
# 218                                          637.15
# 220                                          362.13
#
#      Cases - newly reported in last 7 days  \
# 213                                      0
# 216                                      0
# 217                                      0
# 218                                      0
# ...

# %%
new_mbusa.describe()
# Out:
#        Cases - cumulative total  \
# count              5.600000e+01
# mean               1.308872e+06
# std                5.106454e+06
# min                7.000000e+00
# 25%                2.086500e+03
# 50%                1.554650e+04
# 75%                3.417105e+05
# max                3.342940e+07
#
#        Cases - cumulative total per 100000 population  \
# count                                       56.000000
# mean                                      4089.820893
# std                                       3304.720199
# min                                        102.940000
# 25%                                       1395.055000
# 50%                                       3173.840000
# 75%                                       6266.230000
# max                                      10767.070000
#
#        Cases - newly reported in last 7 days  \
# count                              56.000000
# mean                            16953.767857
# ...

# %%
new_mbusa.dtypes
# Out:
# Name                                                             object
# WHO Region                                                       object
# Cases - cumulative total                                          int64
# Cases - cumulative total per 100000 population                  float64
# Cases - newly reported in last 7 days                             int64
# Cases - newly reported in last 7 days per 100000 population     float64
# Cases - newly reported in last 24 hours                           int64
# Deaths - cumulative total                                         int64
# Deaths - cumulative total per 100000 population                 float64
# Deaths - newly reported in last 7 days                            int64
# Deaths - newly reported in last 7 days per 100000 population    float64
# Deaths - newly reported in last 24 hours                          int64
# Transmission Classification                                      object
# dtype: object

# %%
new_mbusa['WHO Region'].value_counts().to_frame()
# Out:
#           WHO Region
# Americas          56

# %%
new_mbusa.shape
# Out:
# (56, 13)

# %%
new_mbusa['Transmission Classification'].value_counts().to_frame()
# Out:
#                         Transmission Classification
# Community transmission                           42
# Sporadic cases                                    5
# Clusters of cases                                 5
# No cases                                          4

# %%
subsetdata_set = new_mbusa[['Name','Cases - cumulative total','Deaths - cumulative total']]
subsetdata_set.head()
# Out:
#                         Name  Cases - cumulative total  \
# 1   United States of America                  33429396
# 3                     Brazil                  18855015
# 8                  Argentina                   4574340
# 9                   Colombia                   4402582
# 15                    Mexico                   2549862
#
#     Deaths - cumulative total
# 1                      600930
# 3                      526892
# 8                       96983
# 9                      110019
# 15                     233958

# %%
sorteddata_set = subsetdata_set.sort_values(by=['Deaths - cumulative total'],
                                          ascending= False)
sorteddata_set.head()
# Out:
#                         Name  Cases - cumulative total  \
# 1   United States of America                  33429396
# 3                     Brazil                  18855015
# 15                    Mexico                   2549862
# 19                      Peru                   2069051
# 9                   Colombia                   4402582
#
#     Deaths - cumulative total
# 1                      600930
# 3                      526892
# 15                     233958
# 19                     193588
# 9                      110019

# %%
sorteddata_set.tail()
# Out:
#                             Name  Cases - cumulative total  \
# 212                     Anguilla                       111
# 213  Falkland Islands (Malvinas)                        60
# 216    Saint Pierre and Miquelon                        26
# 218               Sint Eustatius                        20
# 220                         Saba                         7
#
#      Deaths - cumulative total
# 212                          0
# 213                          0
# 216                          0
# 218                          0
# 220                          0

# %%
subsetdata_set = new_mbusa[['Name','Cases - newly reported in last 24 hours','Deaths - newly reported in last 24 hours']]
subsetdata_set.head()
# Out:
#                         Name  Cases - newly reported in last 24 hours  \
# 1   United States of America                                    36990
# 3                     Brazil                                    62504
# 8                  Argentina                                    21590
# 9                   Colombia                                    26721
# 15                    Mexico                                     7989
#
#     Deaths - newly reported in last 24 hours
# 1                                        473
# 3                                       1780
# 8                                        462
# 9                                        553
# 15                                       269

# %%
subsetdata_set.tail()
# Out:
#                             Name  Cases - newly reported in last 24 hours  \
# 213  Falkland Islands (Malvinas)                                        0
# 216    Saint Pierre and Miquelon                                        0
# 217                   Montserrat                                        0
# 218               Sint Eustatius                                        0
# 220                         Saba                                        0
#
#      Deaths - newly reported in last 24 hours
# 213                                         0
# 216                                         0
# 217                                         0
# 218                                         0
# 220                                         0

# %%
subsetdata_set = new_mbusa[['Name','Cases - newly reported in last 24 hours','Transmission Classification']]
subsetdata_set.head()
# Out:
#                         Name  Cases - newly reported in last 24 hours  \
# 1   United States of America                                    36990
# 3                     Brazil                                    62504
# 8                  Argentina                                    21590
# 9                   Colombia                                    26721
# 15                    Mexico                                     7989
#
#    Transmission Classification
# 1       Community transmission
# 3       Community transmission
# 8       Community transmission
# 9       Community transmission
# 15      Community transmission

# %%
sorteddata_set = subsetdata_set.sort_values(by=['Cases - newly reported in last 24 hours'],
                                          ascending= False)
sorteddata_set.head()
# Out:
#                         Name  Cases - newly reported in last 24 hours  \
# 3                     Brazil                                    62504
# 1   United States of America                                    36990
# 9                   Colombia                                    26721
# 8                  Argentina                                    21590
# 15                    Mexico                                     7989
#
#    Transmission Classification
# 3       Community transmission
# 1       Community transmission
# 9       Community transmission
# 8       Community transmission
# 15      Community transmission
